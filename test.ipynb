# %%
for i in range(1,13):
    if i < 10:
        print(f'0{i}', end=' ')
    else:
        print(i, end=' ')
print('')


c = 36
c1 = 13
while c >= 31:
    print(c, end=' ')
    print(' '* 29, end=' ')
    print(c1)
    c -= 1
    c1 +=1
for i in range(30, 18, -1):
    print(i, end = ' ')
# Out:
# 01 02 03 04 05 06 07 08 09 10 11 12
# 36                               13
# 35                               14
# 34                               15
# 33                               16
# 32                               17
# 31                               18
# 30 29 28 27 26 25 24 23 22 21 20 19

# %%
from case import Case
import random

types_possibles = ['Camembert', 'Normale']
categories = ['Base de données', 'Python', 'Unix', 'Actu IA', 'Devops',"Personnalité de l'IA"]
indice_cases_camembert = [1,7,13,19,25,31]

liste_cases = []
cat = categories.copy()
for i in indice_cases_camembert:
    
    cat_case = random.choice(cat)
    cat.remove(cat_case)
    new_case = Case(categorie= cat_case,position = i, type = types_possibles[0])
    liste_cases.append(new_case)





for i in liste_cases:
    print(i.position)
# Out:
# 1
# 7
# 13
# 19
# 25
# 31

# %%
from case import Case
import random



types_possibles = ['Camembert', 'Normale']
categories = ['Base de données', 'Python', 'Unix', 'Actu IA', 'Devops',"Personnalité de l'IA"]


liste_cases = []
cat_cam = categories.copy()
for i in range(1,37):
    if i == 1 or i % 6 == 1:
        cat_case = random.choice(cat_cam)
        cat_cam.remove(cat_case)
        new_case = Case(categorie= cat_case,position = i, type = types_possibles[0])
        liste_cases.append(new_case)
        cat = categories.copy()
        cat.remove(cat_case)


    else:
        cat_case_normale = random.choice(cat)
        cat.remove(cat_case_normale)
        new_case = Case(categorie= cat_case_normale,position = i, type = types_possibles[1])
        liste_cases.append(new_case)



for i in liste_cases:
    print(f'{i.type}, {i.position},  {i.categorie}')
# Out:
# Camembert, 1,  Unix
# Normale, 2,  Python
# Normale, 3,  Base de données
# Normale, 4,  Devops
# Normale, 5,  Personnalité de l'IA
# Normale, 6,  Actu IA
# Camembert, 7,  Actu IA
# Normale, 8,  Base de données
# Normale, 9,  Unix
# Normale, 10,  Devops
# Normale, 11,  Python
# Normale, 12,  Personnalité de l'IA
# Camembert, 13,  Base de données
# Normale, 14,  Actu IA
# Normale, 15,  Python
# Normale, 16,  Unix
# Normale, 17,  Devops
# Normale, 18,  Personnalité de l'IA
# Camembert, 19,  Devops
# Normale, 20,  Unix
# Normale, 21,  Actu IA
# Normale, 22,  Python
# Normale, 23,  Personnalité de l'IA
# Normale, 24,  Base de données
# Camembert, 25,  Python
# Normale, 26,  Unix
# Normale, 27,  Base de données
# Normale, 28,  Actu IA
# Normale, 29,  Devops
# Normale, 30,  Personnalité de l'IA
# Camembert, 31,  Personnalité de l'IA
# Normale, 32,  Unix
# Normale, 33,  Actu IA
# Normale, 34,  Devops
# Normale, 35,  Python
# Normale, 36,  Base de données

# %%
liste_cases
# Out:
# [<case.Case at 0x7e71e917b920>,
#  <case.Case at 0x7e71e917aa20>,
#  <case.Case at 0x7e71e9179970>,
#  <case.Case at 0x7e71e9179d30>,
#  <case.Case at 0x7e71e917b4d0>,
#  <case.Case at 0x7e71e917b8f0>,
#  <case.Case at 0x7e71e9179be0>,
#  <case.Case at 0x7e71e9179130>,
#  <case.Case at 0x7e71e917bcb0>,
#  <case.Case at 0x7e71e9179190>,
#  <case.Case at 0x7e71e91794f0>,
#  <case.Case at 0x7e71e9179b50>,
#  <case.Case at 0x7e71e9179880>,
#  <case.Case at 0x7e71e9179ca0>,
#  <case.Case at 0x7e71e917aea0>,
#  <case.Case at 0x7e71e9179ac0>,
#  <case.Case at 0x7e71e9179250>,
#  <case.Case at 0x7e71e9178d40>,
#  <case.Case at 0x7e71e917ac30>,
#  <case.Case at 0x7e71e9179ee0>,
#  <case.Case at 0x7e71e917b140>,
#  <case.Case at 0x7e71e9178620>,
#  <case.Case at 0x7e71e9179f10>,
#  <case.Case at 0x7e71e917bf80>,
#  <case.Case at 0x7e71e91797c0>,
#  <case.Case at 0x7e71e91793a0>,
#  <case.Case at 0x7e71e917bd70>,
#  <case.Case at 0x7e71e917bb90>,
#  <case.Case at 0x7e71e917a750>,
#  <case.Case at 0x7e71e917a1e0>,
#  <case.Case at 0x7e71e9178dd0>,
#  <case.Case at 0x7e71e917bef0>,
#  <case.Case at 0x7e71e917ae70>,
#  <case.Case at 0x7e71e917a690>,
#  <case.Case at 0x7e71e917a8a0>,
#  <case.Case at 0x7e71e917a5a0>]

# %%
emojis = [
    "🟦",  # Carré bleu
    "🟩",  # Carré vert
    "🟥",  # Carré rouge
    "🟨",  # Carré jaune
    "🟧",  # Carré orange
    "🟪",  # Carré violet
]

emojis_ronds = [
    "🔵",  # Cercle bleu
    "🟢",  # Cercle vert
    "🔴",  # Cercle rouge
    "🟡",  # Cercle jaune
    "🟠",  # Cercle orange
    "🟣",  # Cercle violet
]

for i in range(1,13):
    
    if i < 13:
        if liste_cases[i-1].categorie == categories[0]:
            print(emojis[0], end = '   ')

        if liste_cases[i-1].categorie == categories[1]:
            print(emojis[1], end = '   ')

        if liste_cases[i-1].categorie == categories[2]:
            print(emojis[2], end = '   ')

        if liste_cases[i-1].categorie == categories[3]:
            print(emojis[3], end = '   ')

        if liste_cases[i-1].categorie == categories[4]:
            print(emojis[4], end = '   ')

        if liste_cases[i-1].categorie == categories[5]:
            print(emojis[5], end = '   ')
            
print('\n')


c = 36
c1 = 13
while c >= 31:
    if liste_cases[c-1].categorie == categories[0]:
        print(emojis[0], end = '   ')

    if liste_cases[c-1].categorie == categories[1]:
        print(emojis[1], end = '   ')

    if liste_cases[c-1].categorie == categories[2]:
        print(emojis[2], end = '   ')

    if liste_cases[c-1].categorie == categories[3]:
        print(emojis[3], end = '   ')

    if liste_cases[c-1].categorie == categories[4]:
        print(emojis[4], end = '   ')

    if liste_cases[c-1].categorie == categories[5]:
        print(emojis[5], end = '   ')
            
    print(' '* 48, end = '   ')

    if liste_cases[c1-1].categorie == categories[0]:
        print(emojis[0], end='\n\n')

    if liste_cases[c1-1].categorie == categories[1]:
        print(emojis[1], end='\n\n')

    if liste_cases[c1-1].categorie == categories[2]:
        print(emojis[2], end='\n\n')

    if liste_cases[c1-1].categorie == categories[3]:
        print(emojis[3], end='\n\n')

    if liste_cases[c1-1].categorie == categories[4]:
        print(emojis[4], end='\n\n')

    if liste_cases[c1-1].categorie == categories[5]:
        print(emojis[5], end='\n\n')
    c -= 1
    c1 +=1
for i in range(30, 18, -1):
    if liste_cases[i-1].categorie == categories[0]:
        print(emojis[0], end= '   ')

    if liste_cases[i-1].categorie == categories[1]:
        print(emojis[1], end = '   ')

    if liste_cases[i-1].categorie == categories[2]:
        print(emojis[2], end = '   ')

    if liste_cases[i-1].categorie == categories[3]:
        print(emojis[3], end = '   ')

    if liste_cases[i-1].categorie == categories[4]:
        print(emojis[4], end = '   ')

    if liste_cases[i-1].categorie == categories[5]:
        print(emojis[5], end = '   ')
# Out:
# 🟥   🟩   🟦   🟧   🟪   🟨   🟨   🟦   🟥   🟧   🟩   🟪
#
# 🟦                                                      🟦
#
# 🟩                                                      🟨
#
# 🟧                                                      🟩
#
# 🟨                                                      🟥
#
# 🟥                                                      🟧
#
# 🟪                                                      🟪
#
# 🟪   🟧   🟨   🟦   🟥   🟩   🟦   🟪   🟩   🟨   🟥   🟧

# %%
for i in range(1,13):

    if i < 10:
        print(f'0{i}', end=' ')
    else:
        print(i, end=' ')
print('')


c = 36
c1 = 13
while c >= 31:
    print(c, end=' ')
    print(' '* 29, end=' ')
    print(c1)
    c -= 1
c1 +=1
for i in range(30, 18, -1):
    print(i, end = ' ')
# Out:
# 01 02 03 04 05 06 07 08 09 10 11 12
# 36                               13
# 35                               13
# 34                               13
# 33                               13
# 32                               13
# 31                               13
# 30 29 28 27 26 25 24 23 22 21 20 19
